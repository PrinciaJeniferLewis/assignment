# %%
print("welcome to the revision class of python")
# Out:
# welcome to the revision class of python

# %%
print('welcome to the revision class of python')
# Out:
# welcome to the revision class of python

# %%
if 5>2:
  print("welcome to the revision class of python")
# Out:
# welcome to the revision class of python

# %%
if 5>12:
  print("welcome to the revision class of python")

# %%
if 5>12:
  print("welcome to the revision class of python")
print("welcome to the class")
# Out:
# welcome to the class

# %%
x=5
y="Hello world"

# %%
x
# Out:
# 5

# %%
y
# Out:
# 'Hello world'

# %%
#this is acomment
print("welcome to the revision class of python")
# Out:
# welcome to the revision class of python

# %%
x=5
y="hello world"
print(x)
print(y)
# Out:
# 5
# hello world

# %%
x=5
y="hello world"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x=50.5
y=1j
print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'complex'>

# %%
x=["apple","banana","watermelon"]
y=range(6)
print(type(x))
print(type(y))
# Out:
# <class 'list'>
# <class 'range'>

# %%
x=("apple","banana","watermelon")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={"Name":"apple","type":"fruit"}
print(type(x))
print(x)
# Out:
# <class 'dict'>
# {'Name': 'apple', 'type': 'fruit'}

# %%
x=frozenset({"Name","apple","orange","cherry"})
print(type(x))
print(x)
# Out:
# <class 'frozenset'>
# frozenset({'cherry', 'apple', 'Name', 'orange'})

# %%
x=True
print(type(x))
print(x)
# Out:
# <class 'bool'>
# True

# %%
x=b"hello"
print(type(x))
print(x)
# Out:
# <class 'bytes'>
# b'hello'

# %%
x=bytearray(5)
print(type(x))
print(x)
# Out:
# <class 'bytearray'>
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
x=memoryview(bytes(5))
x

# %%
x=1#int
y=2.8#float
z=1j#complex

# %%
y
# Out:
# 2.8

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
type(x)
type(y)
type(z)
# Out:
# complex

# %%
x=int(1)
y=int(9.8)
z=int('3')
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=str("hii")
y=str(9.8)
z=str(3)
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'str'>

# %%
a=''' my name is princia,
      from AE,
      Acharya institute'''

# %%
print (a)
# Out:
#  my name is princia,
#       from AE,
#       Acharya institute

# %%
print(10>9)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("B is greater than A")
else:
  print("B is not greater than A")
# Out:
# B is not greater than A

# %%
a=20
b=33
if b>a:
  print("B is greater than A")
else:
  print("B is not greater than A")
# Out:
# B is greater than A

# %%
print(10+5)
# Out:
# 15

# %%
x=2
y=4
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
# Out:
# 6
# -2
# 8
# 0.5
# 2
# 16
# 0

# %%
thisislist=["apple","banana","grapes"]
thisislist
# Out:
# ['apple', 'banana', 'grapes']

# %%
thisislist=["apple","banana","grapes","apples1","bananal","grapes1"]

# %%
print(thisislist[1])
# Out:
# banana

# %%
print(thisislist[0:2])
# Out:
# ['apple', 'banana']

# %%
print(thisislist[0:4])
# Out:
# ['apple', 'banana', 'grapes', 'apples1']

# %%
print(thisislist[-1])
# Out:
# grapes1

# %%
print(thisislist[:4])
# Out:
# ['apple', 'banana', 'grapes', 'apples1']

# %%
print(thisislist[2:])
# Out:
# ['grapes', 'apples1', 'bananal', 'grapes1']

# %%
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apples1', 'bananal', 'grapes1']

# %%
thisislist[1]="blackcurrent"

# %%
print(thisislist)
# Out:
# ['apple', 'blackcurrent', 'grapes', 'apples1', 'bananal', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist[1]=["blackcurrent","watermelon"]
print(thisislist)
# Out:
# ['apple', ['blackcurrent', 'watermelon'], 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist[4]=["jackfruit"]
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apple1', ['jackfruit'], 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.insert(1,"orange")
print(thisislist)
# Out:
# ['apple', 'orange', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.insert(2,"orange")
print(thisislist)
# Out:
# ['apple', 'banana', 'orange', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
tropical=["mango","pineapple","papaya","mango","pineapple1","papaya1"]
thisislist.extend(tropical)
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1', 'mango', 'pineapple', 'papaya', 'mango', 'pineapple1', 'papaya1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisistuple=["mango","pineapple","papaya","mango","pineapple1","papaya1"]
thisislist.extend(thisistuple)
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1', 'mango', 'pineapple', 'papaya', 'mango', 'pineapple1', 'papaya1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.remove("banana")
print(thisislist)
# Out:
# ['apple', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.remove("apple1")
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.pop()
print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apple1', 'banana1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.pop(0)
print(thisislist)
# Out:
# ['banana', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist
# Out:
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
del thisislist

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
thisislist.clear()
print(thisislist)
# Out:
# []

# %%
thisislist=["apple","banana","grapes","apple1","banana1","grapes1"]
for i in range (len(thisislist)):
 print(thisislist)
# Out:
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']
# ['apple', 'banana', 'grapes', 'apple1', 'banana1', 'grapes1']

# %%
thisislist = ["apple","banana","grapes","apple1","banana1","grapes1"]
for x in thisislist:
 print(x)
# Out:
# apple
# banana
# grapes
# apple1
# banana1
# grapes1

# %%
thisislist = ["apple","banana","grapes","apple1","banana1","grapes1"]
i=i+1
while i< len(thisislist):
 print(thisislist)

# %%
thislist =["apple","banana","cherry"]
[print (x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
fruits =  ["Apple","Banana","Cherry","kiwi","mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)
print(newlist)
# Out:
# ['Banana', 'mango']

# %%
fruits =  ["apple","Banana","Cherry","kiwi","mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)
print(newlist)
# Out:
# ['apple', 'Banana', 'mango']

# %%
fruits =  ["apple","Banana","Cherry","kiwi","mango"]
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'Banana', 'mango']
