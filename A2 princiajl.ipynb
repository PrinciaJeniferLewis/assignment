# %%
import pandas as pd

# %%
s = pd.Series([6, 2, -5, 1], index=['a', 'b', 'c', 'd'])

# %%
s
# Out:
# a    6
# b    2
# c   -5
# d    1
# dtype: int64

# %%
data = {'Country': ['Japan', 'India',"France"], 'Capital': ['Tokyo', 'New Delhi', 'Paris'],'Population': [126476461, 1303171035, 65334344]}

# %%
data
# Out:
# {'Capital': ['Tokyo', 'New Delhi', 'Paris'],
#  'Country': ['Japan', 'India', 'France'],
#  'Population': [126476461, 1303171035, 65334344]}

# %%
df = pd.DataFrame(data,
                  columns=['Country', 'Capital', 'Population'])

# %%
df.head()
# Out:
#   Country    Capital  Population
# 0   Japan      Tokyo   126476461
# 1   India  New Delhi  1303171035
# 2  France      Paris    65334344
