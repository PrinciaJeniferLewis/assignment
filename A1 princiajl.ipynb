# %% [markdown]
# **Variables and Datatypes**

# %% [markdown]
# Variables assignment

# %%
x=8

# %%
x
# Out:
# 8

# %% [markdown]
# Calculations with variables(sum,subtraction,product,remainder,exponential)

# %%
x+4
# Out:
# 12

# %%
x-2
# Out:
# 6

# %%
x*7
# Out:
# 56

# %%
x/6
# Out:
# 1.3333333333333333

# %%
x**2
# Out:
# 64

# %%
x**3
# Out:
# 512

# %%
x%6
# Out:
# 2

# %% [markdown]
# # Types and Type conversion

# %%
int(7),int(5.1)
# Out:
# (7, 5)

# %%
str("2"),str("False")
# Out:
# ('2', 'False')

# %%
float("2.5"),float("7")
# Out:
# (2.5, 7.0)

# %%
bool(),bool(4),bool(3.5),bool(-8)
# Out:
# (False, True, True, True)

# %% [markdown]
# # Strings

# %%
my_string="My name is Princia JL  "

# %%
my_string
# Out:
# 'My name is Princia JL  '

# %% [markdown]
# String operations

# %%
my_string * 3
# Out:
# 'My name is Princia JL  My name is Princia JL  My name is Princia JL  '

# %%
my_string+ "from AE"
# Out:
# 'My name is Princia JL  from AE'

# %%
"r" in my_string
# Out:
# True

# %%
"z" in my_string
# Out:
# False
