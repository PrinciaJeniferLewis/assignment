# %% [markdown]
# **Introduction to Pandas**

# %%
# creating a simple python list
a=[1,4,3,7,5,8,6,2]
a
# Out:
# [1, 4, 3, 7, 5, 8, 6, 2]

# %%
#convert the list into an pandas object calledb series 
import pandas as pd
a=pd.Series(a)
a
# Out:
# 0    1
# 1    4
# 2    3
# 3    7
# 4    5
# 5    8
# 6    6
# 7    2
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Simple series operation such as sorting, sum,max and count**

# %%
a.max()
# Out:
# 8

# %%
a.min()
# Out:
# 1

# %%
a.sort_values()
# Out:
# 0    1
# 7    2
# 2    3
# 1    4
# 4    5
# 6    6
# 3    7
# 5    8
# dtype: int64

# %%
a.sort_values(ascending=False)
# Out:
# 5    8
# 3    7
# 6    6
# 4    5
# 1    4
# 2    3
# 7    2
# 0    1
# dtype: int64

# %%
a.sort_values(ascending=False,inplace=True)

# %%
a.value_counts()
# Out:
# 8    1
# 7    1
# 6    1
# 5    1
# 4    1
# 3    1
# 2    1
# 1    1
# dtype: int64

# %%
a[:1]
# Out:
# 5    8
# dtype: int64

# %%
data={
    'apples':[3,2,9,5],
    'oranges':[4,3,5,0]
    
}

# %%
purchases=pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        4
# 1       2        3
# 2       9        5
# 3       5        0

# %%
purchases=pd.DataFrame(data,index=['Lily','Lola','Laila','Lisa'])

# %%
purchases
# Out:
#        apples  oranges
# Lily        3        4
# Lola        2        3
# Laila       9        5
# Lisa        5        0
