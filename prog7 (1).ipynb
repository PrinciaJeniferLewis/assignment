# %%
import pandas as pd
file_name = "/content/amazon_fires.csv"
df = pd.read_csv(file_name, encoding = "ISO-8859-1")
df.head(10)
# Out:
#     ano      mes estado    numero    encontro
# 0  1998  Janeiro   Acre   0 Fires  01-01-1998
# 1  1999  Janeiro   Acre   0 Fires  01-01-1999
# 2  2000  Janeiro   Acre   0 Fires  01-01-2000
# 3  2001  Janeiro   Acre   0 Fires  01-01-2001
# 4  2002  Janeiro   Acre   0 Fires  01-01-2002
# 5  2003  Janeiro   Acre  10 Fires  01-01-2003
# 6  2004  Janeiro   Acre   0 Fires  01-01-2004
# 7  2005  Janeiro   Acre  12 Fires  01-01-2005
# 8  2006  Janeiro   Acre   4 Fires  01-01-2006
# 9  2007  Janeiro   Acre   0 Fires  01-01-2007

# %%
df["estado"].unique()
# Out:
# array(['Acre', 'alagoas', 'Amapa'], dtype=object)

# %%
new_columns = {'ano' : 'year',
               'estado' : ' state', 
               'mes' : 'month',
               'numero' : 'number_of_fires',
               'encontro' : 'date'}
df.rename(columns=new_columns, inplace=True)
df.head()
# Out:
#    year    month  state number_of_fires        date
# 0  1998  Janeiro   Acre         0 Fires  01-01-1998
# 1  1999  Janeiro   Acre         0 Fires  01-01-1999
# 2  2000  Janeiro   Acre         0 Fires  01-01-2000
# 3  2001  Janeiro   Acre         0 Fires  01-01-2001
# 4  2002  Janeiro   Acre         0 Fires  01-01-2002

# %%
df['year'].unique()
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             515 non-null    int64
#  1   month            515 non-null    object
#  2    state           515 non-null    object
#  3   number_of_fires  510 non-null    object
#  4   date             515 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 20.2+ KB
#    year    month  state number_of_fires        date
# 0  1998  Janeiro   Acre         0 Fires  01-01-1998
# 1  1999  Janeiro   Acre         0 Fires  01-01-1999
# 2  2000  Janeiro   Acre         0 Fires  01-01-2000
# 3  2001  Janeiro   Acre         0 Fires  01-01-2001
# 4  2002  Janeiro   Acre         0 Fires  01-01-2002

# %%
new_order =[4,3,2,0,1]
df=df[df.columns[new_order]]
df.head()
# Out:
#          date number_of_fires  state  year    month
# 0  01-01-1998         0 Fires   Acre  1998  Janeiro
# 1  01-01-1999         0 Fires   Acre  1999  Janeiro
# 2  01-01-2000         0 Fires   Acre  2000  Janeiro
# 3  01-01-2001         0 Fires   Acre  2001  Janeiro
# 4  01-01-2002         0 Fires   Acre  2002  Janeiro

# %%
df.head(10)
# Out:
#          date number_of_fires  state  year    month
# 0  01-01-1998         0 Fires   Acre  1998  Janeiro
# 1  01-01-1999         0 Fires   Acre  1999  Janeiro
# 2  01-01-2000         0 Fires   Acre  2000  Janeiro
# 3  01-01-2001         0 Fires   Acre  2001  Janeiro
# 4  01-01-2002         0 Fires   Acre  2002  Janeiro
# 5  01-01-2003        10 Fires   Acre  2003  Janeiro
# 6  01-01-2004         0 Fires   Acre  2004  Janeiro
# 7  01-01-2005        12 Fires   Acre  2005  Janeiro
# 8  01-01-2006         4 Fires   Acre  2006  Janeiro
# 9  01-01-2007         0 Fires   Acre  2007  Janeiro

# %%
df.head(25)
# Out:
#           date number_of_fires  state  year      month
# 0   01-01-1998         0 Fires   Acre  1998    Janeiro
# 1   01-01-1999         0 Fires   Acre  1999    Janeiro
# 2   01-01-2000         0 Fires   Acre  2000    Janeiro
# 3   01-01-2001         0 Fires   Acre  2001    Janeiro
# 4   01-01-2002         0 Fires   Acre  2002    Janeiro
# 5   01-01-2003        10 Fires   Acre  2003    Janeiro
# 6   01-01-2004         0 Fires   Acre  2004    Janeiro
# 7   01-01-2005        12 Fires   Acre  2005    Janeiro
# 8   01-01-2006         4 Fires   Acre  2006    Janeiro
# 9   01-01-2007         0 Fires   Acre  2007    Janeiro
# 10  01-01-2008         0 Fires   Acre  2008    Janeiro
# 11  01-01-2009         0 Fires   Acre  2009    Janeiro
# 12  01-01-2010         1 Fires   Acre  2010    Janeiro
# 13  01-01-2011         0 Fires   Acre  2011    Janeiro
# 14  01-01-2012         0 Fires   Acre  2012    Janeiro
# 15  01-01-2013         0 Fires   Acre  2013    Janeiro
# 16  01-01-2014         0 Fires   Acre  2014    Janeiro
# 17  01-01-2015         1 Fires   Acre  2015    Janeiro
# 18  01-01-2016        12 Fires   Acre  2016    Janeiro
# 19  01-01-2017         0 Fires   Acre  2017    Janeiro
# 20  01-01-1998         0 Fires   Acre  1998  Fevereiro
# 21  01-01-1999         0 Fires   Acre  1999  Fevereiro
# 22  01-01-2000         0 Fires   Acre  2000  Fevereiro
# 23  01-01-2001         0 Fires   Acre  2001  Fevereiro
# 24  01-01-2002         1 Fires   Acre  2002  Fevereiro

# %%
df.tail()
# Out:
#            date number_of_fires  state  year      month
# 510  01-01-2009               0  Amapa  2009  Fevereiro
# 511  01-01-2010               0  Amapa  2010  Fevereiro
# 512  01-01-2011               3  Amapa  2011  Fevereiro
# 513  01-01-2012               5  Amapa  2012  Fevereiro
# 514  01-01-2013               0  Amapa  2013  Fevereiro

# %%
df.tail(10)
# Out:
#            date number_of_fires  state  year      month
# 505  01-01-2004               2  Amapa  2004  Fevereiro
# 506  01-01-2005               1  Amapa  2005  Fevereiro
# 507  01-01-2006               2  Amapa  2006  Fevereiro
# 508  01-01-2007               0  Amapa  2007  Fevereiro
# 509  01-01-2008               0  Amapa  2008  Fevereiro
# 510  01-01-2009               0  Amapa  2009  Fevereiro
# 511  01-01-2010               0  Amapa  2010  Fevereiro
# 512  01-01-2011               3  Amapa  2011  Fevereiro
# 513  01-01-2012               5  Amapa  2012  Fevereiro
# 514  01-01-2013               0  Amapa  2013  Fevereiro

# %%
df.tail(25)
# Out:
#            date number_of_fires  state  year      month
# 490  01-01-2009               4  Amapa  2009    Janeiro
# 491  01-01-2010               2  Amapa  2010    Janeiro
# 492  01-01-2011               0  Amapa  2011    Janeiro
# 493  01-01-2012              30  Amapa  2012    Janeiro
# 494  01-01-2013               3  Amapa  2013    Janeiro
# 495  01-01-2014              10  Amapa  2014    Janeiro
# 496  01-01-2015              14  Amapa  2015    Janeiro
# 497  01-01-2016              19  Amapa  2016    Janeiro
# 498  01-01-2017               2  Amapa  2017    Janeiro
# 499  01-01-1998               0  Amapa  1998  Fevereiro
# 500  01-01-1999               1  Amapa  1999  Fevereiro
# 501  01-01-2000               0  Amapa  2000  Fevereiro
# 502  01-01-2001               0  Amapa  2001  Fevereiro
# 503  01-01-2002               2  Amapa  2002  Fevereiro
# 504  01-01-2003               0  Amapa  2003  Fevereiro
# 505  01-01-2004               2  Amapa  2004  Fevereiro
# 506  01-01-2005               1  Amapa  2005  Fevereiro
# 507  01-01-2006               2  Amapa  2006  Fevereiro
# 508  01-01-2007               0  Amapa  2007  Fevereiro
# 509  01-01-2008               0  Amapa  2008  Fevereiro
# 510  01-01-2009               0  Amapa  2009  Fevereiro
# 511  01-01-2010               0  Amapa  2010  Fevereiro
# 512  01-01-2011               3  Amapa  2011  Fevereiro
# 513  01-01-2012               5  Amapa  2012  Fevereiro
# 514  01-01-2013               0  Amapa  2013  Fevereiro

# %% [markdown]
# **Determine if the columns contain numerical data**

# %%
df["number_of_fires"].str.isdigit()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 510     True
# 511     True
# 512     True
# 513     True
# 514     True
# Name: number_of_fires, Length: 515, dtype: object

# %%
df["number_of_fires"].astype(str).str.isdigit()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 510     True
# 511     True
# 512     True
# 513     True
# 514     True
# Name: number_of_fires, Length: 515, dtype: bool

# %%
df['number_of_fires'].str.strip("Fires")
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#        ..
# 510     0
# 511     0
# 512     3
# 513     5
# 514     0
# Name: number_of_fires, Length: 515, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             515 non-null    object
#  1   number_of_fires  510 non-null    object
#  2    state           515 non-null    object
#  3   year             515 non-null    int64
#  4   month            515 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 20.2+ KB

# %%
filename = "/content/amazon_fires.csv"
df = pd.read_csv(file_name,encoding = "ISO-8859-1")
new_columns = {'ano' : 'year',
               'estado' : ' state', 
               'mes' : 'month',
               'numero' : 'number_of_fires',
               'encontro' : 'date'}
df.rename(columns=new_columns, inplace=True)
df['number_of_fires']=df['number_of_fires'].str.strip("Fires")
df.head()
# Out:
#    year    month  state number_of_fires        date
# 0  1998  Janeiro   Acre              0   01-01-1998
# 1  1999  Janeiro   Acre              0   01-01-1999
# 2  2000  Janeiro   Acre              0   01-01-2000
# 3  2001  Janeiro   Acre              0   01-01-2001
# 4  2002  Janeiro   Acre              0   01-01-2002

# %%
df.isnull()
# Out:
#       year  month   state  number_of_fires   date
# 0    False  False   False            False  False
# 1    False  False   False            False  False
# 2    False  False   False            False  False
# 3    False  False   False            False  False
# 4    False  False   False            False  False
# ..     ...    ...     ...              ...    ...
# 510  False  False   False            False  False
# 511  False  False   False            False  False
# 512  False  False   False            False  False
# 513  False  False   False            False  False
# 514  False  False   False            False  False
#
# [515 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# year               0
# month              0
#  state             0
# number_of_fires    5
# date               0
# dtype: int64

# %%
df=df.dropna()
df=df.reset_index()
df.head()
# Out:
#    index  year    month  state number_of_fires        date
# 0      0  1998  Janeiro   Acre              0   01-01-1998
# 1      1  1999  Janeiro   Acre              0   01-01-1999
# 2      2  2000  Janeiro   Acre              0   01-01-2000
# 3      3  2001  Janeiro   Acre              0   01-01-2001
# 4      4  2002  Janeiro   Acre              0   01-01-2002

# %%
df.isnull().sum()
# Out:
# index              0
# year               0
# month              0
#  state             0
# number_of_fires    0
# date               0
# dtype: int64

# %%
df.tail()
# Out:
#      index  year      month  state number_of_fires        date
# 505    510  2009  Fevereiro  Amapa               0  01-01-2009
# 506    511  2010  Fevereiro  Amapa               0  01-01-2010
# 507    512  2011  Fevereiro  Amapa               3  01-01-2011
# 508    513  2012  Fevereiro  Amapa               5  01-01-2012
# 509    514  2013  Fevereiro  Amapa               0  01-01-2013

# %%
df.info()

# %%
filename = "/content/amazon_fires.csv"
df = pd.read_csv(file_name,encoding = "ISO-8859-1")
new_columns = {'ano' : 'year',
               'estado' : ' state', 
               'mes' : 'month',
               'numero' : 'number_of_fires',
               'encontro' : 'date'}
df.rename(columns=new_columns, inplace=True)
df['number_of_fires']=df['number_of_fires'].str.strip("Fires")
df.head()

# %%
df= df.drop(['month','date'],axis=1)
df.head()
# Out:
#    year  state number_of_fires
# 0  1998   Acre              0
# 1  1999   Acre              0
# 2  2000   Acre              0
# 3  2001   Acre              0
# 4  2002   Acre              0

# %%
df= df.drop(df.index[0])
df = df.reset_index()
df.head()

# %%
df= df.drop(df.index[[2,3]])
df = df.reset_index()
df.head()

# %%
df= df.drop(df.index[1:4])
df.head()
